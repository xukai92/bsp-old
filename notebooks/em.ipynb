# %%
using InteractiveUtils, DrWatson, Comonicon
if isdefined(Main, :IJulia) && Main.IJulia.inited
    using Revise
else
    ENV["GKSwstype"] = 100 # suppress warnings during gif saving
end
versioninfo()
@quickactivate
# Out:
# Julia Version 1.6.0
# Commit f9720dc2eb (2021-03-24 12:55 UTC)
# Platform Info:
#   OS: Linux (x86_64-pc-linux-gnu)
#   CPU: Intel(R) Xeon(R) CPU E5-2620 v3 @ 2.40GHz
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-11.0.1 (ORCJIT, haswell)
# Environment:
#   JULIA_NUM_THREADS = 10

# %%
using Plots, ProgressMeter, Logging
theme(:bright; size=(300, 300))

# %%
using Random, Turing, BayesianSymbolic
using ExprOptimization.ExprRules

includef(args...) = isdefined(Main, :Revise) ? includet(args...) : include(args...)
includef(srcdir("utility.jl"))
includef(srcdir("app_inf.jl"))
includef(srcdir("sym_reg.jl"))
includef(srcdir("exp_max.jl"))
includef(srcdir("analyse.jl"))
includef(srcdir("dataset.jl"))
# Suppress warnings of using _varinfo
with_logger(SimpleLogger(stderr, Logging.Error)) do
    includef(srcdir("scenarios", "magnet.jl"))
    includef(srcdir("scenarios", "nbody.jl"))
    includef(srcdir("scenarios", "bounce.jl"))
    includef(srcdir("scenarios", "mat.jl"))
end
# Out:
# ┌ Info: Precompiling BayesianSymbolic [d95aa7d0-ea3e-4103-b443-9ed45b862455]
# └ @ Base loading.jl:1317
# ┌ Info: Skipping precompilation since __precompile__(false). Importing BayesianSymbolic [d95aa7d0-ea3e-4103-b443-9ed45b862455].
# └ @ Base loading.jl:1025
# ┌ Warning: skipping callee #_#38 (called by nothing) due to UndefRefError()
# └ @ LoweredCodeUtils /afs/inf.ed.ac.uk/user/s16/s1672897/.julia/packages/LoweredCodeUtils/poBmh/src/signatures.jl:279
# WARNING: redefinition of constant PHYS101_FALL_CONFIGS. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant PHYS101_SPRING_CONFIGS. This may fail, cause incorrect answers, or produce other errors.

# %%
using PyCall
pd = pyimport("pandas")
# Out:
# PyObject <module 'pandas' from '/afs/inf.ed.ac.uk/user/s16/s1672897/miniconda3/envs/ml/lib/python3.9/site-packages/pandas/__init__.py'>

# %%
function report_synth(dataset; rg_seed=1:5, rg_shuffleseed=1:5, namewithweak=false)
    dataset = "synth/$dataset"
    df = pd.DataFrame(
        columns=("Method", "Normliased RMSE (train)", "Normliased RMSE (test)", "EM seed", "Data seed")
    )
    forces = Dict{Int, Any}()

    count = 1
    @showprogress for seed in rg_seed, shuffleseed in rg_shuffleseed
        hps = (ntrains=5, seed=seed, shuffleseed=shuffleseed)
        if namewithweak
            hps = (hps..., weak=false)
        end

        dir = datadir(dataset)
        scenarios, attributes = loaddata(dir, hps.ntrains; shuffleseed=hps.shuffleseed)
        scenarios_test, attributes_test = loaddata(dir, 20; shuffleseed=hps.shuffleseed, istrain=false)

        local res
        try
            res = wload(resultsdir(dataset, savename(hps; connector="-"), "em.jld2"))
        catch
            println("seed $(hps.seed) unfinished")
        end

        @unpack ScenarioModel, latentname, ealg, malg, elike, mlike, trace = res

        for (force, method) in [(trace[end].force, "BSP"), (ZeroForce(), "Zero")]
            if method == "BSP"
                forceexpr = BayesianSymbolic.get_executable(force.tree, force.grammar)
                @info "Count $count" forceexpr
                # Track expressions
                forces[count] = (force.constant, forceexpr)
            end
            evalres = evalforce(ScenarioModel, scenarios, attributes, force, ealg, elike, mlike)
            evalres_test = evalforce(ScenarioModel, scenarios_test, attributes_test, force, ealg, elike, mlike)

            # Add to data frame
            df.loc[count] = [method, evalres.normrmse, evalres_test.normrmse, seed, shuffleseed]
            count = count + 1
        end
    end
    
    return df, forces
end

function savedf(df, dataset)
    df.groupby(["Method"]).get_group("BSP").to_csv("pretty_paper/raw/em-$dataset-bsp.csv", columns=["Normliased RMSE (test)", "EM seed", "Data seed"], header=false)
    df.groupby(["Method"]).get_group("Zero").to_csv("pretty_paper/raw/em-$dataset-zero.csv", columns=["Normliased RMSE (test)", "EM seed", "Data seed"], header=false)
end
# Out:
# savedf (generic function with 1 method)

# %% [markdown]
# NBODY

# %%
df, forces = report_synth("nbody")
df
# Out:
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# Progress:  20%|████████▎                                |  ETA: 0:06:55┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# Progress:  40%|████████████████▍                        |  ETA: 0:04:48┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# Progress:  60%|████████████████████████▋                |  ETA: 0:03:10┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# Progress:  80%|████████████████████████████████▊        |  ETA: 0:01:33┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# ┌ Info:
# │   size(attributes[1]) = (3,)
# │   size(ms[1]) = (3,)
# └ @ Main /afs/inf.ed.ac.uk/user/s16/s1672897/projects/bayesian_symbolic_physics/src/analyse.jl:79
# Progress: 100%|█████████████████████████████████████████| Time: 0:07:48
# PyObject    Method  Normliased RMSE (train)  Normliased RMSE (test) EM seed Data seed
# 0     BSP                 0.684291                0.789963       1         1
# 1    Zero                 1.318852                1.767886       1         1
# 2     BSP                 0.601253                1.067499       1         2
# 3    Zero                 1.301966                1.767886       1         2
# 4     BSP                 0.583036                0.783484       1         3
# 5    Zero                 1.477320                1.767886       1         3
# 6     BSP                 0.659762                0.785545       1         4
# 7    Zero                 1.705750                1.767886       1         4
# 8     BSP                 0.380639                0.771298       1         5
# 9    Zero                 1.077788                1.767886       1         5
# 10    BSP                 1.030368                1.375284       2         1
# 11   Zero                 1.318852                1.767886       2         1
# 12    BSP                 0.396250                0.794058       2         2
# 13   Zero                 1.301966                1.767886       2         2
# 14    BSP                 0.584618                0.779463       2         3
# 15   Zero                 1.477320                1.767886       2         3
# 16    BSP                 0.634471                0.783368       2         4
# 17   Zero                 1.705750                1.767886       2         4
# 18    BSP                 0.412068                0.805368       2         5
# 19   Zero                 1.077788                1.767886       2         5
# 20    BSP                 0.175091                0.220545       3         1
# 21   Zero                 1.318852                1.767886       3         1
# 22    BSP                 0.788058                1.194012       3         2
# 23   Zero                 1.301966                1.767886       3         2
# 24    BSP                 0.583494                0.783738       3         3
# 25   Zero                 1.477320                1.767886       3         3
# 26    BSP                 0.644021                0.883019       3         4
# 27   Zero                 1.705750                1.767886       3         4
# 28    BSP                 0.687331                1.226075       3         5
# 29   Zero                 1.077788                1.767886       3         5
# 30    BSP                 0.847616                0.751006       4         1
# 31   Zero                 1.318852                1.767886       4         1
# 32    BSP                 0.610192                1.070037       4         2
# 33   Zero                 1.301966                1.767886       4         2
# 34    BSP                 0.859181                1.071254       4         3
# 35   Zero                 1.477320                1.767886       4         3
# 36    BSP                 0.914208                1.070178       4         4
# 37   Zero                 1.705750                1.767886       4         4
# 38    BSP                 0.588220                1.086574       4         5
# 39   Zero                 1.077788                1.767886       4         5
# 40    BSP                 0.343811                0.319238       5         1
# 41   Zero                 1.318852                1.767886       5         1
# 42    BSP                 0.790898                1.298652       5         2
# 43   Zero                 1.301966                1.767886       5         2
# 44    BSP                 0.521535                0.803034       5         3
# 45   Zero                 1.477320                1.767886       5         3
# 46    BSP                 0.742055                0.832176       5         4
# 47   Zero                 1.705750                1.767886       5         4
# 48    BSP                 0.588212                1.086409       5         5
# 49   Zero                 1.077788                1.767886       5         5

# %%
savedf(df, "nbody")

# %%
df.groupby(["Method"]).median()
# Out:
# PyObject         Normliased RMSE (train)  Normliased RMSE (test)
# Method
# BSP                    0.610192                0.805368
# Zero                   1.318852                1.767886

# %%
df.groupby(["Method"]).quantile([.25, .75])
# Out:
# PyObject              Normliased RMSE (train)  Normliased RMSE (test)
# Method
# BSP    0.25                 0.583066                0.783145
#        0.75                 0.729911                1.071264
# Zero   0.25                 1.301966                1.767886
#        0.75                 1.477320                1.767886

# %% [markdown]
# BOUNCE

# %%
df, forces = report_synth("bounce")
df
# Out:
# ┌ Info: Count 1
# │   forceexpr = c2 * bmul(bmul(mi, bdiv(bsub(pi, c), bnorm(bsub(pi, c)))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 3
# │   forceexpr = c2 * bmul(bmul(mi, bdiv(bsub(pi, c), bnorm(bsub(pi, c)))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 5
# │   forceexpr = c1 * bmul(bmul(bdiv(bmul(mi, mj), mj), bdiv(bsub(pi, c), bnorm(bsub(pi, c)))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 7
# │   forceexpr = c3 * bmul(bmul(bpow2(bnorm(bsub(vi, vj))), bdiv(bsub(pi, c), bnorm(bsub(pi, c)))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 9
# │   forceexpr = c2 * bmul(bmul(bdiv(bpow2(bproject(bsub(vi, vj), bnormalize(bsub(pi, c)))), bnorm(bsub(pi, c))), bnormalize(bsub(pi, c))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# Progress:  20%|████████▎                                |  ETA: 0:13:36┌ Info: Count 11
# │   forceexpr = c3 * bmul(bmul(bdiv(bpow2(mi), mi), bnormalize(bsub(pi, pj))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 13
# │   forceexpr = c3 * bmul(bmul(bdiv(bpow2(mi), mi), bnormalize(bsub(pi, pj))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 15
# │   forceexpr = c1 * bmul(bmul(mi, bdiv(bsub(pi, pj), bnorm(bsub(pi, pj)))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 17
# │   forceexpr = c1 * bmul(bmul(bnorm(vi), bnormalize(bsub(pi, c))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 19
# │   forceexpr = c1 * bmul(bmul(bnorm(vi), bnormalize(bsub(pi, c))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# Progress:  40%|████████████████▍                        |  ETA: 0:09:08┌ Info: Count 21
# │   forceexpr = c3 * bmul(bmul(mi, bnormalize(bsub(pi, pj))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 23
# │   forceexpr = c2 * bmul(bmul(bdiv(bmul(mi, mj), mj), bnormalize(bsub(pi, c))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 25
# │   forceexpr = c2 * bmul(bmul(bdiv(bmul(mi, mj), mj), bnormalize(bsub(pi, c))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 27
# │   forceexpr = c3 * bmul(bmul(bpow2(bnorm(bsub(vi, vj))), bnormalize(bsub(pi, c))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 29
# │   forceexpr = c3 * bmul(bmul(bnorm(bsub(vi, vj)), bnormalize(bsub(pi, c))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# Progress:  60%|████████████████████████▋                |  ETA: 0:05:49┌ Info: Count 31
# │   forceexpr = c3 * bmul(bmul(bdiv(bmul(mi, mj), mj), bnormalize(bsub(pi, c))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 33
# │   forceexpr = c3 * bmul(bmul(bdiv(bmul(mi, mj), mj), bnormalize(bsub(pi, c))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 35
# │   forceexpr = c3 * bmul(bmul(bdiv(bmul(mi, mj), mj), bnormalize(bsub(pi, c))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 37
# │   forceexpr = c3 * bmul(bmul(bpow2(bnorm(vi)), bnormalize(bsub(pi, c))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 39
# │   forceexpr = c2 * bmul(bmul(bdiv(bmul(mi, mj), mj), bdiv(bsub(pi, c), bproject(bsub(pi, pj), bdiv(bsub(pi, c), bproject(bsub(pi, pj), bdiv(bsub(pi, pj), bproject(bsub(pi, c), bdiv(bsub(pi, c), bnorm(bsub(pi, pj)))))))))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# Progress:  80%|████████████████████████████████▊        |  ETA: 0:03:15┌ Info: Count 41
# │   forceexpr = c3 * bmul(bmul(bdiv(bpow2(mi), mi), bnormalize(bsub(pi, c))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 43
# │   forceexpr = c3 * bmul(bmul(bdiv(bpow2(mi), mi), bnormalize(bsub(pi, c))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 45
# │   forceexpr = c1 * bmul(bmul(bmul(bpow2(bnorm(bsub(pi, c))), bdiv(bpow2(mi), mi)), bnormalize(bsub(pi, c))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 47
# │   forceexpr = c2 * bmul(bmul(bdiv(bnorm(vi), mi), bdiv(bsub(pi, c), bproject(bsub(pi, pj), bnormalize(bsub(pi, c))))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# ┌ Info: Count 49
# │   forceexpr = c2 * bmul(bmul(bmul(bnorm(vi), bnorm(bsub(vi, vj))), bdiv(bsub(pi, c), bnorm(bsub(pi, pj)))), does_collide(si, pi, sj, pj))
# └ @ Main In[68]:31
# Progress: 100%|█████████████████████████████████████████| Time: 0:17:55
# PyObject    Method  Normliased RMSE (train)  Normliased RMSE (test) EM seed Data seed
# 0     BSP                 0.014592                0.031284       1         1
# 1    Zero                 0.040964                0.059844       1         1
# 2     BSP                 0.014345                0.031053       1         2
# 3    Zero                 0.046966                0.059844       1         2
# 4     BSP                 0.024974                0.030933       1         3
# 5    Zero                 0.060070                0.059844       1         3
# 6     BSP                 0.060910                0.021666       1         4
# 7    Zero                 0.117996                0.059844       1         4
# 8     BSP                 0.060931                0.032982       1         5
# 9    Zero                 0.119737                0.059844       1         5
# 10    BSP                 0.024057                0.042671       2         1
# 11   Zero                 0.040964                0.059844       2         1
# 12    BSP                 0.023489                0.042675       2         2
# 13   Zero                 0.046966                0.059844       2         2
# 14    BSP                 0.034514                0.042844       2         3
# 15   Zero                 0.060070                0.059844       2         3
# 16    BSP                 0.050869                0.020957       2         4
# 17   Zero                 0.117996                0.059844       2         4
# 18    BSP                 0.052617                0.022268       2         5
# 19   Zero                 0.119737                0.059844       2         5
# 20    BSP                 0.024057                0.042671       3         1
# 21   Zero                 0.040964                0.059844       3         1
# 22    BSP                 0.014345                0.031053       3         2
# 23   Zero                 0.046966                0.059844       3         2
# 24    BSP                 0.024974                0.030933       3         3
# 25   Zero                 0.060070                0.059844       3         3
# 26    BSP                 0.083249                0.032525       3         4
# 27   Zero                 0.117996                0.059844       3         4
# 28    BSP                 0.048572                0.018253       3         5
# 29   Zero                 0.119737                0.059844       3         5
# 30    BSP                 0.014592                0.031284       4         1
# 31   Zero                 0.040964                0.059844       4         1
# 32    BSP                 0.014345                0.031053       4         2
# 33   Zero                 0.046966                0.059844       4         2
# 34    BSP                 0.024974                0.030933       4         3
# 35   Zero                 0.060070                0.059844       4         3
# 36    BSP                 0.053672                0.023311       4         4
# 37   Zero                 0.117996                0.059844       4         4
# 38    BSP                 0.055173                0.054514       4         5
# 39   Zero                 0.119737                0.059844       4         5
# 40    BSP                 0.014592                0.031284       5         1
# 41   Zero                 0.040964                0.059844       5         1
# 42    BSP                 0.014345                0.031053       5         2
# 43   Zero                 0.046966                0.059844       5         2
# 44    BSP                 0.027064                0.033816       5         3
# 45   Zero                 0.060070                0.059844       5         3
# 46    BSP                 0.044581                0.017972       5         4
# 47   Zero                 0.117996                0.059844       5         4
# 48    BSP                 0.073449                0.024868       5         5
# 49   Zero                 0.119737                0.059844       5         5

# %%
df.groupby(["Method"]).median()
# Out:
# PyObject         Normliased RMSE (train)  Normliased RMSE (test)
# Method
# BSP                    0.024974                0.031563
# Zero                   0.060070                0.059844

# %%
df.groupby(["Method"]).quantile([.25, .75])
# Out:
# PyObject              Normliased RMSE (train)  Normliased RMSE (test)
# Method
# BSP    0.25                 0.014592                0.031053
#        0.75                 0.055263                0.039364
# Zero   0.25                 0.046966                0.059844
#        0.75                 0.117996                0.059844

# %% [markdown]
# MAT

# %%
df, forces = report_synth("mat"; rg_seed=0:9, rg_shuffleseed=-1:1, namewithweak=true)
df
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:04:14
# PyObject    Method  Normliased RMSE (train)  Normliased RMSE (test) EM seed Data seed
# 0     BSP                 0.000235                0.000759       0        -1
# 1    Zero                 0.001148                0.001199       0        -1
# 2     BSP                 0.000212                0.000358       0         0
# 3    Zero                 0.000972                0.001199       0         0
# 4     BSP                 0.000028                0.000539       0         1
# 5    Zero                 0.000579                0.001199       0         1
# 6     BSP                 0.000304                0.001642       1        -1
# 7    Zero                 0.001148                0.001199       1        -1
# 8     BSP                 0.000212                0.000358       1         0
# 9    Zero                 0.000972                0.001199       1         0
# 10    BSP                 0.000028                0.000539       1         1
# 11   Zero                 0.000579                0.001199       1         1
# 12    BSP                 0.000235                0.000759       2        -1
# 13   Zero                 0.001148                0.001199       2        -1
# 14    BSP                 0.000212                0.000358       2         0
# 15   Zero                 0.000972                0.001199       2         0
# 16    BSP                 0.000110                0.001170       2         1
# 17   Zero                 0.000579                0.001199       2         1
# 18    BSP                 0.000235                0.000759       3        -1
# 19   Zero                 0.001148                0.001199       3        -1
# 20    BSP                 0.000212                0.000358       3         0
# 21   Zero                 0.000972                0.001199       3         0
# 22    BSP                 0.000097                0.000739       3         1
# 23   Zero                 0.000579                0.001199       3         1
# 24    BSP                 0.000127                0.004248       4        -1
# 25   Zero                 0.001148                0.001199       4        -1
# 26    BSP                 0.000212                0.000358       4         0
# 27   Zero                 0.000972                0.001199       4         0
# 28    BSP                 0.000028                0.000539       4         1
# 29   Zero                 0.000579                0.001199       4         1
# 30    BSP                 0.000433                0.001059       5        -1
# 31   Zero                 0.001148                0.001199       5        -1
# 32    BSP                 0.000212                0.000358       5         0
# 33   Zero                 0.000972                0.001199       5         0
# 34    BSP                 0.000028                0.000539       5         1
# 35   Zero                 0.000579                0.001199       5         1
# 36    BSP                 0.000396                0.003187       6        -1
# 37   Zero                 0.001148                0.001199       6        -1
# 38    BSP                 0.000212                0.000358       6         0
# 39   Zero                 0.000972                0.001199       6         0
# 40    BSP                 0.000028                0.000539       6         1
# 41   Zero                 0.000579                0.001199       6         1
# 42    BSP                 0.000289                0.001218       7        -1
# 43   Zero                 0.001148                0.001199       7        -1
# 44    BSP                 0.000212                0.000358       7         0
# 45   Zero                 0.000972                0.001199       7         0
# 46    BSP                 0.000090                0.000729       7         1
# 47   Zero                 0.000579                0.001199       7         1
# 48    BSP                 0.000002                0.000002       8        -1
# 49   Zero                 0.001148                0.001199       8        -1
# 50    BSP                 0.000212                0.000358       8         0
# 51   Zero                 0.000972                0.001199       8         0
# 52    BSP                 0.000028                0.000539       8         1
# 53   Zero                 0.000579                0.001199       8         1
# 54    BSP                 0.000173                0.000764       9        -1
# 55   Zero                 0.001148                0.001199       9        -1
# 56    BSP                 0.000212                0.000358       9         0
# 57   Zero                 0.000972                0.001199       9         0
# 58    BSP                 0.000062                0.000829       9         1
# 59   Zero                 0.000579                0.001199       9         1

# %%
df.groupby(["Method"]).median()
# Out:
# PyObject         Normliased RMSE (train)  Normliased RMSE (test)
# Method
# BSP                    0.000212                0.000539
# Zero                   0.000972                0.001199

# %%
df.groupby(["Method"]).quantile([.25, .75])
# Out:
# PyObject              Normliased RMSE (train)  Normliased RMSE (test)
# Method
# BSP    0.25                 0.000069                0.000358
#        0.75                 0.000212                0.000763
# Zero   0.25                 0.000579                0.001199
#        0.75                 0.001148                0.001199

# %%
df.groupby(["Method"]).mean()
# Out:
# PyObject         Normliased RMSE (train)  Normliased RMSE (test)
# Method
# BSP                    0.000169                0.000823
# Zero                   0.000899                0.001199

# %%
df.groupby(["Method"]).std()
# Out:
# PyObject         Normliased RMSE (train)  Normliased RMSE (test)
# Method
# BSP                    0.000112                0.000864
# Zero                   0.000242                0.000000

# %%
df.groupby(["Method"]).min()
# Out:
# PyObject         Normliased RMSE (train)  Normliased RMSE (test)  EM seed  Data seed
# Method
# BSP                    0.000002                0.000002        0         -1
# Zero                   0.000579                0.001199        0         -1

# %%
df.groupby(["Method"]).max()
# Out:
# PyObject         Normliased RMSE (train)  Normliased RMSE (test)  EM seed  Data seed
# Method
# BSP                    0.000433                0.004248        9          1
# Zero                   0.001148                0.001199        9          1
